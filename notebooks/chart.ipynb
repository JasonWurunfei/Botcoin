# %%
import sys
# Add the src directory to the Python path
sys.path.insert(0, '../src')

# %%
from botcoin.data.historical import YfDataManager
from botcoin.utils.visual.chart import plot_candlestick

# %%
SYMBOL = 'NVDA'

# %%
dm = YfDataManager()
df = dm.get_maximum_1min_data(SYMBOL)

# %%
plot_candlestick(df, title=f'{SYMBOL} 1-Minute Candlestick Chart')
